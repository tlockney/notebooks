# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 10, 20)
y = x**2

# %%
plt.plot(x,y)
plt.title('Our first plot')
plt.xlabel('X label')
plt.ylabel('Y label')
# Out:
# Text(0,0.5,'Y label')
