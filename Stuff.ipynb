# %% [markdown]
# # Matplotlib examples
#
# Trying out some stuff from [Introduction to Matplotlib — Data Visualization in Python](https://heartbeat.fritz.ai/introduction-to-matplotlib-data-visualization-in-python-d9143287ae39)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 10, 20)
y = x**2

# %%
plt.plot(x,y)
plt.title('Our first plot')
plt.xlabel('X axis label')
plt.ylabel('Y axis label')
# Out:
# Text(0, 0.5, 'Y axis label')
